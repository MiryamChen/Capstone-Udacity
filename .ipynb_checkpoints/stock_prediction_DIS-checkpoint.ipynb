# %%
import yfinance as yf
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-08-10 14:40:01.543494: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# 1. get data
# 2. prepare data
# 3. standardize data
# 4. train/test split
# 5. build training and predicting pipeline: that allows to quickly train and evaluate models

# %%
#set variables, we start with Disney stock
stock_symbol = 'DIS'
start_date = '2022-01-01'
end_date = '2023-07-30'

# %%
df=yf.download(stock_symbol, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  155.830002  157.559998  155.360001  156.759995  156.759995
# 2022-01-04  158.589996  160.320007  155.550003  155.729996  155.729996
# 2022-01-05  156.520004  159.380005  155.100006  155.190002  155.190002
# 2022-01-06  156.240005  157.770004  153.679993  156.899994  156.899994
# 2022-01-07  156.899994  159.300003  156.289993  157.830002  157.830002
#
#               Volume
# Date
# 2022-01-03  10222800
# 2022-01-04  16582000
# 2022-01-05  12272100
# 2022-01-06  11095300
# 2022-01-07   9554600

# %%
#delete nan if any
df = df[['Open', 'High', 'Low', 'Volume', 'Adj Close']].dropna()

# %%
# Separate features and target variables, 
#leave 'close' out, as it is the same as 'adj close' in most cases and could bias the model 
X = df[['Open', 'High', 'Low', 'Volume']]
y = df['Adj Close']

# %%
#set cutoff date for training and testing data
test_size = 60

# %%
# Split scaled data into training,  and testing sets
X_train = X[:-test_size]
X_test = X[-test_size:]
y_train = y[:-test_size]
y_test = y[-test_size:]

# %%
# Standardize features using MinMaxScaler - not necessary in this case as all features are in same scale
#but will keep this step as it transform the data into numpy array, which is the format needed for ML
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
#only apply transform test data so that data is not leaked
X_validation_scaled = scaler.transform(X_validation)
X_test_scaled = scaler.transform(X_test)

# %%
#reshape data for lstm: LSTM models expect input data in a 3D shape (samples, time steps, features)
#time steps: is the number of times periods in the dataset(days, months...)that you want to take as input for prediction
# Reshape X_train_scaled

X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))

# Reshape X_test_scaled
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 5
#       1 #reshape data for lstm: LSTM models expect input data in a 3D shape (samples, time steps, features)
#       2 #time steps: is the number of times periods in the dataset(days, months...)that you want to take as input for prediction
#       3 # Reshape X_train_scaled
# ----> 5 X_train_reshaped = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
#       7 # Reshape X_test_scaled
#       8 X_test_reshaped = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
#
# File ~/opt/anaconda3/envs/UdacityProject/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
#build and train the LSTM Model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dense(50)) #activation='relu'))
model.add(Dense(1))

# %%
# Define the optimizer with a learning rate
optimizer = Adam(learning_rate=0.001)  # Adjust the learning rate as needed

# %%
# Compile the model
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
# Train the model with validation data and early stopping
model.fit(X_train_reshaped, y_train,
                    epochs=500,
                    batch_size=50,
                    verbose=2)  # Early stopping
# Out:
# Epoch 1/500
# 7/7 - 1s - loss: 12612.5020 - mean_absolute_error: 110.7262 - 958ms/epoch - 137ms/step
# Epoch 2/500
# 7/7 - 0s - loss: 12142.7754 - mean_absolute_error: 108.6586 - 19ms/epoch - 3ms/step
# Epoch 3/500
# 7/7 - 0s - loss: 9978.2549 - mean_absolute_error: 97.9585 - 19ms/epoch - 3ms/step
# Epoch 4/500
# 7/7 - 0s - loss: 5944.3516 - mean_absolute_error: 69.1051 - 18ms/epoch - 3ms/step
# Epoch 5/500
# 7/7 - 0s - loss: 3781.5950 - mean_absolute_error: 51.5285 - 18ms/epoch - 3ms/step
# Epoch 6/500
# 7/7 - 0s - loss: 3603.2231 - mean_absolute_error: 53.5754 - 18ms/epoch - 3ms/step
# Epoch 7/500
# 7/7 - 0s - loss: 3056.9631 - mean_absolute_error: 46.7836 - 17ms/epoch - 2ms/step
# Epoch 8/500
# 7/7 - 0s - loss: 2795.5774 - mean_absolute_error: 42.2256 - 17ms/epoch - 2ms/step
# Epoch 9/500
# 7/7 - 0s - loss: 2630.8071 - mean_absolute_error: 40.3053 - 17ms/epoch - 2ms/step
# Epoch 10/500
# 7/7 - 0s - loss: 2453.2881 - mean_absolute_error: 39.0687 - 18ms/epoch - 3ms/step
# Epoch 11/500
# 7/7 - 0s - loss: 2319.6519 - mean_absolute_error: 37.6647 - 18ms/epoch - 3ms/step
# Epoch 12/500
# 7/7 - 0s - loss: 2205.3250 - mean_absolute_error: 36.1507 - 18ms/epoch - 3ms/step
# Epoch 13/500
# 7/7 - 0s - loss: 2105.6487 - mean_absolute_error: 34.6321 - 18ms/epoch - 3ms/step
# Epoch 14/500
# 7/7 - 0s - loss: 2015.2233 - mean_absolute_error: 33.2368 - 17ms/epoch - 2ms/step
# Epoch 15/500
# 7/7 - 0s - loss: 1933.9775 - mean_absolute_error: 32.0638 - 17ms/epoch - 2ms/step
# Epoch 16/500
# 7/7 - 0s - loss: 1861.2026 - mean_absolute_error: 31.4377 - 16ms/epoch - 2ms/step
# Epoch 17/500
# 7/7 - 0s - loss: 1791.8375 - mean_absolute_error: 30.9371 - 17ms/epoch - 2ms/step
# Epoch 18/500
# 7/7 - 0s - loss: 1726.4824 - mean_absolute_error: 30.4489 - 17ms/epoch - 2ms/step
# Epoch 19/500
# 7/7 - 0s - loss: 1664.0067 - mean_absolute_error: 30.0615 - 17ms/epoch - 2ms/step
# Epoch 20/500
# 7/7 - 0s - loss: 1603.2771 - mean_absolute_error: 29.7963 - 18ms/epoch - 3ms/step
# Epoch 21/500
# 7/7 - 0s - loss: 1544.4761 - mean_absolute_error: 29.4448 - 18ms/epoch - 3ms/step
# Epoch 22/500
# 7/7 - 0s - loss: 1486.0746 - mean_absolute_error: 29.1411 - 17ms/epoch - 2ms/step
# Epoch 23/500
# 7/7 - 0s - loss: 1429.4697 - mean_absolute_error: 28.9162 - 18ms/epoch - 3ms/step
# Epoch 24/500
# 7/7 - 0s - loss: 1370.4862 - mean_absolute_error: 28.4004 - 17ms/epoch - 2ms/step
# Epoch 25/500
# 7/7 - 0s - loss: 1313.1333 - mean_absolute_error: 28.0685 - 18ms/epoch - 3ms/step
# Epoch 26/500
# 7/7 - 0s - loss: 1253.9308 - mean_absolute_error: 27.5324 - 18ms/epoch - 3ms/step
# Epoch 27/500
# 7/7 - 0s - loss: 1194.6371 - mean_absolute_error: 27.1713 - 18ms/epoch - 3ms/step
# Epoch 28/500
# 7/7 - 0s - loss: 1132.7310 - mean_absolute_error: 26.6885 - 18ms/epoch - 3ms/step
# Epoch 29/500
# 7/7 - 0s - loss: 1070.0947 - mean_absolute_error: 26.1894 - 17ms/epoch - 2ms/step
# Epoch 30/500
# 7/7 - 0s - loss: 1007.5266 - mean_absolute_error: 25.6115 - 17ms/epoch - 2ms/step
# Epoch 31/500
# 7/7 - 0s - loss: 945.6772 - mean_absolute_error: 25.0938 - 17ms/epoch - 2ms/step
# Epoch 32/500
# 7/7 - 0s - loss: 882.9512 - mean_absolute_error: 24.4149 - 19ms/epoch - 3ms/step
# Epoch 33/500
# 7/7 - 0s - loss: 821.9985 - mean_absolute_error: 23.6695 - 18ms/epoch - 3ms/step
# Epoch 34/500
# 7/7 - 0s - loss: 762.9438 - mean_absolute_error: 23.0844 - 18ms/epoch - 3ms/step
# Epoch 35/500
# 7/7 - 0s - loss: 706.2188 - mean_absolute_error: 22.4641 - 18ms/epoch - 3ms/step
# Epoch 36/500
# 7/7 - 0s - loss: 650.1401 - mean_absolute_error: 21.6000 - 17ms/epoch - 2ms/step
# Epoch 37/500
# 7/7 - 0s - loss: 597.6752 - mean_absolute_error: 20.7113 - 18ms/epoch - 3ms/step
# Epoch 38/500
# 7/7 - 0s - loss: 548.3238 - mean_absolute_error: 20.1382 - 19ms/epoch - 3ms/step
# Epoch 39/500
# 7/7 - 0s - loss: 502.6272 - mean_absolute_error: 19.5115 - 18ms/epoch - 3ms/step
# Epoch 40/500
# 7/7 - 0s - loss: 459.5500 - mean_absolute_error: 18.6940 - 18ms/epoch - 3ms/step
# Epoch 41/500
# 7/7 - 0s - loss: 421.8142 - mean_absolute_error: 18.0556 - 18ms/epoch - 3ms/step
# Epoch 42/500
# 7/7 - 0s - loss: 387.0236 - mean_absolute_error: 17.3446 - 18ms/epoch - 3ms/step
# Epoch 43/500
# 7/7 - 0s - loss: 356.7521 - mean_absolute_error: 16.7248 - 18ms/epoch - 3ms/step
# Epoch 44/500
# 7/7 - 0s - loss: 329.8420 - mean_absolute_error: 15.8789 - 19ms/epoch - 3ms/step
# Epoch 45/500
# 7/7 - 0s - loss: 306.0359 - mean_absolute_error: 15.2060 - 18ms/epoch - 3ms/step
# Epoch 46/500
# 7/7 - 0s - loss: 285.3732 - mean_absolute_error: 14.7709 - 18ms/epoch - 3ms/step
# Epoch 47/500
# 7/7 - 0s - loss: 268.3691 - mean_absolute_error: 14.2439 - 17ms/epoch - 2ms/step
# Epoch 48/500
# 7/7 - 0s - loss: 254.4164 - mean_absolute_error: 13.6332 - 17ms/epoch - 2ms/step
# Epoch 49/500
# 7/7 - 0s - loss: 242.0173 - mean_absolute_error: 13.2663 - 18ms/epoch - 3ms/step
# Epoch 50/500
# 7/7 - 0s - loss: 231.1136 - mean_absolute_error: 12.8162 - 18ms/epoch - 3ms/step
# Epoch 51/500
# 7/7 - 0s - loss: 222.1697 - mean_absolute_error: 12.2225 - 19ms/epoch - 3ms/step
# Epoch 52/500
# 7/7 - 0s - loss: 216.5761 - mean_absolute_error: 11.8363 - 18ms/epoch - 3ms/step
# Epoch 53/500
# 7/7 - 0s - loss: 209.9271 - mean_absolute_error: 11.4997 - 18ms/epoch - 3ms/step
# Epoch 54/500
# 7/7 - 0s - loss: 205.1002 - mean_absolute_error: 11.2609 - 17ms/epoch - 2ms/step
# Epoch 55/500
# 7/7 - 0s - loss: 200.6281 - mean_absolute_error: 10.9722 - 18ms/epoch - 3ms/step
# Epoch 56/500
# 7/7 - 0s - loss: 197.6507 - mean_absolute_error: 10.5747 - 18ms/epoch - 3ms/step
# Epoch 57/500
# 7/7 - 0s - loss: 194.0792 - mean_absolute_error: 10.4503 - 17ms/epoch - 2ms/step
# Epoch 58/500
# 7/7 - 0s - loss: 191.7754 - mean_absolute_error: 10.3156 - 18ms/epoch - 3ms/step
# Epoch 59/500
# 7/7 - 0s - loss: 189.1836 - mean_absolute_error: 10.0103 - 17ms/epoch - 2ms/step
# Epoch 60/500
# 7/7 - 0s - loss: 187.0469 - mean_absolute_error: 9.8773 - 17ms/epoch - 2ms/step
# Epoch 61/500
# 7/7 - 0s - loss: 185.4042 - mean_absolute_error: 9.7380 - 17ms/epoch - 2ms/step
# Epoch 62/500
# 7/7 - 0s - loss: 183.4156 - mean_absolute_error: 9.7089 - 17ms/epoch - 2ms/step
# Epoch 63/500
# 7/7 - 0s - loss: 182.3841 - mean_absolute_error: 9.5861 - 18ms/epoch - 3ms/step
# Epoch 64/500
# 7/7 - 0s - loss: 180.3825 - mean_absolute_error: 9.4914 - 18ms/epoch - 3ms/step
# Epoch 65/500
# 7/7 - 0s - loss: 179.0843 - mean_absolute_error: 9.4996 - 18ms/epoch - 3ms/step
# Epoch 66/500
# 7/7 - 0s - loss: 177.0947 - mean_absolute_error: 9.3430 - 19ms/epoch - 3ms/step
# Epoch 67/500
# 7/7 - 0s - loss: 175.8340 - mean_absolute_error: 9.1690 - 18ms/epoch - 3ms/step
# Epoch 68/500
# 7/7 - 0s - loss: 174.2367 - mean_absolute_error: 9.2022 - 17ms/epoch - 2ms/step
# Epoch 69/500
# 7/7 - 0s - loss: 172.4736 - mean_absolute_error: 9.2445 - 18ms/epoch - 3ms/step
# Epoch 70/500
# 7/7 - 0s - loss: 172.3161 - mean_absolute_error: 8.9835 - 17ms/epoch - 2ms/step
# Epoch 71/500
# 7/7 - 0s - loss: 167.6691 - mean_absolute_error: 8.8689 - 17ms/epoch - 2ms/step
# Epoch 72/500
# 7/7 - 0s - loss: 165.6675 - mean_absolute_error: 9.0821 - 17ms/epoch - 2ms/step
# Epoch 73/500
# 7/7 - 0s - loss: 164.1856 - mean_absolute_error: 8.7449 - 17ms/epoch - 2ms/step
# Epoch 74/500
# 7/7 - 0s - loss: 156.2375 - mean_absolute_error: 8.5107 - 17ms/epoch - 2ms/step
# Epoch 75/500
# 7/7 - 0s - loss: 151.7522 - mean_absolute_error: 8.6927 - 17ms/epoch - 2ms/step
# Epoch 76/500
# 7/7 - 0s - loss: 145.9551 - mean_absolute_error: 8.3476 - 17ms/epoch - 2ms/step
# Epoch 77/500
# 7/7 - 0s - loss: 142.0681 - mean_absolute_error: 8.0661 - 17ms/epoch - 2ms/step
# Epoch 78/500
# 7/7 - 0s - loss: 138.8008 - mean_absolute_error: 8.0932 - 17ms/epoch - 2ms/step
# Epoch 79/500
# 7/7 - 0s - loss: 135.7752 - mean_absolute_error: 7.9475 - 17ms/epoch - 2ms/step
# Epoch 80/500
# 7/7 - 0s - loss: 133.3329 - mean_absolute_error: 7.8185 - 17ms/epoch - 2ms/step
# Epoch 81/500
# 7/7 - 0s - loss: 131.6776 - mean_absolute_error: 7.9664 - 17ms/epoch - 2ms/step
# Epoch 82/500
# 7/7 - 0s - loss: 128.5896 - mean_absolute_error: 7.7376 - 17ms/epoch - 2ms/step
# Epoch 83/500
# 7/7 - 0s - loss: 126.3913 - mean_absolute_error: 7.5709 - 17ms/epoch - 2ms/step
# Epoch 84/500
# 7/7 - 0s - loss: 123.2141 - mean_absolute_error: 7.5700 - 17ms/epoch - 2ms/step
# Epoch 85/500
# 7/7 - 0s - loss: 120.6924 - mean_absolute_error: 7.4532 - 17ms/epoch - 2ms/step
# Epoch 86/500
# 7/7 - 0s - loss: 118.3339 - mean_absolute_error: 7.3000 - 17ms/epoch - 2ms/step
# Epoch 87/500
# 7/7 - 0s - loss: 115.9612 - mean_absolute_error: 7.3101 - 17ms/epoch - 2ms/step
# Epoch 88/500
# 7/7 - 0s - loss: 113.4140 - mean_absolute_error: 7.2481 - 16ms/epoch - 2ms/step
# Epoch 89/500
# 7/7 - 0s - loss: 111.0162 - mean_absolute_error: 7.1942 - 17ms/epoch - 2ms/step
# Epoch 90/500
# 7/7 - 0s - loss: 108.4906 - mean_absolute_error: 7.0261 - 17ms/epoch - 2ms/step
# Epoch 91/500
# 7/7 - 0s - loss: 105.7346 - mean_absolute_error: 6.9299 - 17ms/epoch - 2ms/step
# Epoch 92/500
# 7/7 - 0s - loss: 103.1644 - mean_absolute_error: 6.9373 - 17ms/epoch - 2ms/step
# Epoch 93/500
# 7/7 - 0s - loss: 101.1023 - mean_absolute_error: 6.7268 - 17ms/epoch - 2ms/step
# Epoch 94/500
# 7/7 - 0s - loss: 97.4409 - mean_absolute_error: 6.7044 - 17ms/epoch - 2ms/step
# Epoch 95/500
# 7/7 - 0s - loss: 94.3032 - mean_absolute_error: 6.6270 - 17ms/epoch - 2ms/step
# Epoch 96/500
# 7/7 - 0s - loss: 91.0931 - mean_absolute_error: 6.3084 - 17ms/epoch - 2ms/step
# Epoch 97/500
# 7/7 - 0s - loss: 87.4494 - mean_absolute_error: 6.4618 - 17ms/epoch - 2ms/step
# Epoch 98/500
# 7/7 - 0s - loss: 83.5892 - mean_absolute_error: 6.1688 - 16ms/epoch - 2ms/step
# Epoch 99/500
# 7/7 - 0s - loss: 79.4222 - mean_absolute_error: 6.0528 - 17ms/epoch - 2ms/step
# Epoch 100/500
# 7/7 - 0s - loss: 76.2775 - mean_absolute_error: 5.8456 - 16ms/epoch - 2ms/step
# Epoch 101/500
# 7/7 - 0s - loss: 71.5376 - mean_absolute_error: 5.8487 - 16ms/epoch - 2ms/step
# Epoch 102/500
# 7/7 - 0s - loss: 67.0219 - mean_absolute_error: 5.5859 - 16ms/epoch - 2ms/step
# Epoch 103/500
# 7/7 - 0s - loss: 63.2594 - mean_absolute_error: 5.2695 - 17ms/epoch - 2ms/step
# Epoch 104/500
# 7/7 - 0s - loss: 58.4699 - mean_absolute_error: 5.3798 - 17ms/epoch - 2ms/step
# Epoch 105/500
# 7/7 - 0s - loss: 54.1377 - mean_absolute_error: 5.0032 - 17ms/epoch - 2ms/step
# Epoch 106/500
# 7/7 - 0s - loss: 49.8184 - mean_absolute_error: 4.9236 - 17ms/epoch - 2ms/step
# Epoch 107/500
# 7/7 - 0s - loss: 46.3685 - mean_absolute_error: 4.7574 - 17ms/epoch - 2ms/step
# Epoch 108/500
# 7/7 - 0s - loss: 43.4421 - mean_absolute_error: 4.5274 - 17ms/epoch - 2ms/step
# Epoch 109/500
# 7/7 - 0s - loss: 39.6989 - mean_absolute_error: 4.3005 - 17ms/epoch - 2ms/step
# Epoch 110/500
# 7/7 - 0s - loss: 37.0180 - mean_absolute_error: 4.3051 - 16ms/epoch - 2ms/step
# Epoch 111/500
# 7/7 - 0s - loss: 33.7501 - mean_absolute_error: 3.9314 - 16ms/epoch - 2ms/step
# Epoch 112/500
# 7/7 - 0s - loss: 31.4104 - mean_absolute_error: 4.0343 - 16ms/epoch - 2ms/step
# Epoch 113/500
# 7/7 - 0s - loss: 30.1894 - mean_absolute_error: 3.6167 - 18ms/epoch - 3ms/step
# Epoch 114/500
# 7/7 - 0s - loss: 27.5162 - mean_absolute_error: 3.8467 - 17ms/epoch - 2ms/step
# Epoch 115/500
# 7/7 - 0s - loss: 25.2089 - mean_absolute_error: 3.3753 - 17ms/epoch - 2ms/step
# Epoch 116/500
# 7/7 - 0s - loss: 24.0339 - mean_absolute_error: 3.4440 - 17ms/epoch - 2ms/step
# Epoch 117/500
# 7/7 - 0s - loss: 21.0920 - mean_absolute_error: 3.2536 - 17ms/epoch - 2ms/step
# Epoch 118/500
# 7/7 - 0s - loss: 19.4896 - mean_absolute_error: 3.0504 - 17ms/epoch - 2ms/step
# Epoch 119/500
# 7/7 - 0s - loss: 18.3181 - mean_absolute_error: 3.0267 - 17ms/epoch - 2ms/step
# Epoch 120/500
# 7/7 - 0s - loss: 16.9770 - mean_absolute_error: 2.9094 - 17ms/epoch - 2ms/step
# Epoch 121/500
# 7/7 - 0s - loss: 16.0263 - mean_absolute_error: 2.7937 - 18ms/epoch - 3ms/step
# Epoch 122/500
# 7/7 - 0s - loss: 15.1809 - mean_absolute_error: 2.8120 - 17ms/epoch - 2ms/step
# Epoch 123/500
# 7/7 - 0s - loss: 14.4470 - mean_absolute_error: 2.6861 - 17ms/epoch - 2ms/step
# Epoch 124/500
# 7/7 - 0s - loss: 13.7319 - mean_absolute_error: 2.6451 - 17ms/epoch - 2ms/step
# Epoch 125/500
# 7/7 - 0s - loss: 12.9718 - mean_absolute_error: 2.5678 - 17ms/epoch - 2ms/step
# Epoch 126/500
# 7/7 - 0s - loss: 12.4945 - mean_absolute_error: 2.5324 - 17ms/epoch - 2ms/step
# Epoch 127/500
# 7/7 - 0s - loss: 11.9866 - mean_absolute_error: 2.4860 - 17ms/epoch - 2ms/step
# Epoch 128/500
# 7/7 - 0s - loss: 11.4935 - mean_absolute_error: 2.4401 - 17ms/epoch - 2ms/step
# Epoch 129/500
# 7/7 - 0s - loss: 11.1062 - mean_absolute_error: 2.4056 - 17ms/epoch - 2ms/step
# Epoch 130/500
# 7/7 - 0s - loss: 10.7422 - mean_absolute_error: 2.3740 - 17ms/epoch - 2ms/step
# Epoch 131/500
# 7/7 - 0s - loss: 10.3870 - mean_absolute_error: 2.3374 - 18ms/epoch - 3ms/step
# Epoch 132/500
# 7/7 - 0s - loss: 10.1062 - mean_absolute_error: 2.3057 - 17ms/epoch - 2ms/step
# Epoch 133/500
# 7/7 - 0s - loss: 9.8355 - mean_absolute_error: 2.2713 - 17ms/epoch - 2ms/step
# Epoch 134/500
# 7/7 - 0s - loss: 9.6331 - mean_absolute_error: 2.2576 - 18ms/epoch - 3ms/step
# Epoch 135/500
# 7/7 - 0s - loss: 9.3808 - mean_absolute_error: 2.2316 - 17ms/epoch - 2ms/step
# Epoch 136/500
# 7/7 - 0s - loss: 9.1180 - mean_absolute_error: 2.1971 - 17ms/epoch - 2ms/step
# Epoch 137/500
# 7/7 - 0s - loss: 8.8072 - mean_absolute_error: 2.1586 - 17ms/epoch - 2ms/step
# Epoch 138/500
# 7/7 - 0s - loss: 8.6967 - mean_absolute_error: 2.1534 - 17ms/epoch - 2ms/step
# Epoch 139/500
# 7/7 - 0s - loss: 8.4681 - mean_absolute_error: 2.1204 - 16ms/epoch - 2ms/step
# Epoch 140/500
# 7/7 - 0s - loss: 8.3077 - mean_absolute_error: 2.1041 - 17ms/epoch - 2ms/step
# Epoch 141/500
# 7/7 - 0s - loss: 8.1545 - mean_absolute_error: 2.0851 - 17ms/epoch - 2ms/step
# Epoch 142/500
# 7/7 - 0s - loss: 8.0277 - mean_absolute_error: 2.0845 - 17ms/epoch - 2ms/step
# Epoch 143/500
# 7/7 - 0s - loss: 7.8350 - mean_absolute_error: 2.0424 - 18ms/epoch - 3ms/step
# Epoch 144/500
# 7/7 - 0s - loss: 7.7074 - mean_absolute_error: 2.0338 - 17ms/epoch - 2ms/step
# Epoch 145/500
# 7/7 - 0s - loss: 7.5747 - mean_absolute_error: 2.0234 - 17ms/epoch - 2ms/step
# Epoch 146/500
# 7/7 - 0s - loss: 7.5664 - mean_absolute_error: 2.0104 - 17ms/epoch - 2ms/step
# Epoch 147/500
# 7/7 - 0s - loss: 7.4527 - mean_absolute_error: 2.0046 - 17ms/epoch - 2ms/step
# Epoch 148/500
# 7/7 - 0s - loss: 7.2267 - mean_absolute_error: 1.9726 - 17ms/epoch - 2ms/step
# Epoch 149/500
# 7/7 - 0s - loss: 7.1798 - mean_absolute_error: 1.9732 - 17ms/epoch - 2ms/step
# Epoch 150/500
# 7/7 - 0s - loss: 7.1160 - mean_absolute_error: 1.9757 - 17ms/epoch - 2ms/step
# Epoch 151/500
# 7/7 - 0s - loss: 7.1054 - mean_absolute_error: 1.9751 - 17ms/epoch - 2ms/step
# Epoch 152/500
# 7/7 - 0s - loss: 6.9627 - mean_absolute_error: 1.9451 - 18ms/epoch - 3ms/step
# Epoch 153/500
# 7/7 - 0s - loss: 7.2373 - mean_absolute_error: 1.9872 - 18ms/epoch - 3ms/step
# Epoch 154/500
# 7/7 - 0s - loss: 7.2719 - mean_absolute_error: 1.9931 - 18ms/epoch - 3ms/step
# Epoch 155/500
# 7/7 - 0s - loss: 6.9179 - mean_absolute_error: 1.9351 - 17ms/epoch - 2ms/step
# Epoch 156/500
# 7/7 - 0s - loss: 6.6756 - mean_absolute_error: 1.9098 - 17ms/epoch - 2ms/step
# Epoch 157/500
# 7/7 - 0s - loss: 6.7957 - mean_absolute_error: 1.9330 - 17ms/epoch - 2ms/step
# Epoch 158/500
# 7/7 - 0s - loss: 6.4717 - mean_absolute_error: 1.8835 - 17ms/epoch - 2ms/step
# Epoch 159/500
# 7/7 - 0s - loss: 6.4517 - mean_absolute_error: 1.8839 - 16ms/epoch - 2ms/step
# Epoch 160/500
# 7/7 - 0s - loss: 6.6003 - mean_absolute_error: 1.8974 - 17ms/epoch - 2ms/step
# Epoch 161/500
# 7/7 - 0s - loss: 6.6091 - mean_absolute_error: 1.9232 - 17ms/epoch - 2ms/step
# Epoch 162/500
# 7/7 - 0s - loss: 6.4690 - mean_absolute_error: 1.8967 - 17ms/epoch - 2ms/step
# Epoch 163/500
# 7/7 - 0s - loss: 6.3738 - mean_absolute_error: 1.8644 - 15ms/epoch - 2ms/step
# Epoch 164/500
# 7/7 - 0s - loss: 6.2689 - mean_absolute_error: 1.8657 - 17ms/epoch - 2ms/step
# Epoch 165/500
# 7/7 - 0s - loss: 6.0717 - mean_absolute_error: 1.8257 - 17ms/epoch - 2ms/step
# Epoch 166/500
# 7/7 - 0s - loss: 6.0446 - mean_absolute_error: 1.8264 - 17ms/epoch - 2ms/step
# Epoch 167/500
# 7/7 - 0s - loss: 6.0269 - mean_absolute_error: 1.8194 - 17ms/epoch - 2ms/step
# Epoch 168/500
# 7/7 - 0s - loss: 6.0859 - mean_absolute_error: 1.8343 - 17ms/epoch - 2ms/step
# Epoch 169/500
# 7/7 - 0s - loss: 6.0006 - mean_absolute_error: 1.8106 - 17ms/epoch - 2ms/step
# Epoch 170/500
# 7/7 - 0s - loss: 5.8639 - mean_absolute_error: 1.7956 - 16ms/epoch - 2ms/step
# Epoch 171/500
# 7/7 - 0s - loss: 5.8402 - mean_absolute_error: 1.8004 - 17ms/epoch - 2ms/step
# Epoch 172/500
# 7/7 - 0s - loss: 5.8503 - mean_absolute_error: 1.8015 - 17ms/epoch - 2ms/step
# Epoch 173/500
# 7/7 - 0s - loss: 5.8016 - mean_absolute_error: 1.7898 - 17ms/epoch - 2ms/step
# Epoch 174/500
# 7/7 - 0s - loss: 5.7317 - mean_absolute_error: 1.7864 - 17ms/epoch - 2ms/step
# Epoch 175/500
# 7/7 - 0s - loss: 5.7341 - mean_absolute_error: 1.7789 - 17ms/epoch - 2ms/step
# Epoch 176/500
# 7/7 - 0s - loss: 5.7398 - mean_absolute_error: 1.7756 - 17ms/epoch - 2ms/step
# Epoch 177/500
# 7/7 - 0s - loss: 5.7536 - mean_absolute_error: 1.7935 - 17ms/epoch - 2ms/step
# Epoch 178/500
# 7/7 - 0s - loss: 5.7161 - mean_absolute_error: 1.7783 - 16ms/epoch - 2ms/step
# Epoch 179/500
# 7/7 - 0s - loss: 5.5522 - mean_absolute_error: 1.7484 - 17ms/epoch - 2ms/step
# Epoch 180/500
# 7/7 - 0s - loss: 5.5161 - mean_absolute_error: 1.7491 - 16ms/epoch - 2ms/step
# Epoch 181/500
# 7/7 - 0s - loss: 5.5125 - mean_absolute_error: 1.7506 - 17ms/epoch - 2ms/step
# Epoch 182/500
# 7/7 - 0s - loss: 5.5640 - mean_absolute_error: 1.7539 - 17ms/epoch - 2ms/step
# Epoch 183/500
# 7/7 - 0s - loss: 5.5313 - mean_absolute_error: 1.7500 - 18ms/epoch - 3ms/step
# Epoch 184/500
# 7/7 - 0s - loss: 5.5472 - mean_absolute_error: 1.7511 - 17ms/epoch - 2ms/step
# Epoch 185/500
# 7/7 - 0s - loss: 5.5738 - mean_absolute_error: 1.7713 - 17ms/epoch - 2ms/step
# Epoch 186/500
# 7/7 - 0s - loss: 5.4510 - mean_absolute_error: 1.7491 - 17ms/epoch - 2ms/step
# Epoch 187/500
# 7/7 - 0s - loss: 5.3406 - mean_absolute_error: 1.7206 - 17ms/epoch - 2ms/step
# Epoch 188/500
# 7/7 - 0s - loss: 5.3039 - mean_absolute_error: 1.7241 - 17ms/epoch - 2ms/step
# Epoch 189/500
# 7/7 - 0s - loss: 5.3027 - mean_absolute_error: 1.7184 - 17ms/epoch - 2ms/step
# Epoch 190/500
# 7/7 - 0s - loss: 5.2966 - mean_absolute_error: 1.7242 - 17ms/epoch - 2ms/step
# Epoch 191/500
# 7/7 - 0s - loss: 5.3020 - mean_absolute_error: 1.7147 - 17ms/epoch - 2ms/step
# Epoch 192/500
# 7/7 - 0s - loss: 5.2678 - mean_absolute_error: 1.7182 - 17ms/epoch - 2ms/step
# Epoch 193/500
# 7/7 - 0s - loss: 5.1965 - mean_absolute_error: 1.7020 - 17ms/epoch - 2ms/step
# Epoch 194/500
# 7/7 - 0s - loss: 5.1707 - mean_absolute_error: 1.6969 - 16ms/epoch - 2ms/step
# Epoch 195/500
# 7/7 - 0s - loss: 5.1999 - mean_absolute_error: 1.7029 - 16ms/epoch - 2ms/step
# Epoch 196/500
# 7/7 - 0s - loss: 5.1206 - mean_absolute_error: 1.6886 - 17ms/epoch - 2ms/step
# Epoch 197/500
# 7/7 - 0s - loss: 5.0959 - mean_absolute_error: 1.6965 - 17ms/epoch - 2ms/step
# Epoch 198/500
# 7/7 - 0s - loss: 5.1864 - mean_absolute_error: 1.7011 - 17ms/epoch - 2ms/step
# Epoch 199/500
# 7/7 - 0s - loss: 5.1057 - mean_absolute_error: 1.7134 - 17ms/epoch - 2ms/step
# Epoch 200/500
# 7/7 - 0s - loss: 5.1821 - mean_absolute_error: 1.7224 - 17ms/epoch - 2ms/step
# Epoch 201/500
# 7/7 - 0s - loss: 5.0323 - mean_absolute_error: 1.6798 - 17ms/epoch - 2ms/step
# Epoch 202/500
# 7/7 - 0s - loss: 5.0296 - mean_absolute_error: 1.6808 - 17ms/epoch - 2ms/step
# Epoch 203/500
# 7/7 - 0s - loss: 5.0729 - mean_absolute_error: 1.6903 - 17ms/epoch - 2ms/step
# Epoch 204/500
# 7/7 - 0s - loss: 4.9903 - mean_absolute_error: 1.6791 - 17ms/epoch - 2ms/step
# Epoch 205/500
# 7/7 - 0s - loss: 4.9491 - mean_absolute_error: 1.6623 - 17ms/epoch - 2ms/step
# Epoch 206/500
# 7/7 - 0s - loss: 4.9673 - mean_absolute_error: 1.6747 - 16ms/epoch - 2ms/step
# Epoch 207/500
# 7/7 - 0s - loss: 4.9632 - mean_absolute_error: 1.6704 - 16ms/epoch - 2ms/step
# Epoch 208/500
# 7/7 - 0s - loss: 4.9733 - mean_absolute_error: 1.6830 - 16ms/epoch - 2ms/step
# Epoch 209/500
# 7/7 - 0s - loss: 4.9784 - mean_absolute_error: 1.6799 - 17ms/epoch - 2ms/step
# Epoch 210/500
# 7/7 - 0s - loss: 5.0499 - mean_absolute_error: 1.6907 - 17ms/epoch - 2ms/step
# Epoch 211/500
# 7/7 - 0s - loss: 5.0720 - mean_absolute_error: 1.6841 - 17ms/epoch - 2ms/step
# Epoch 212/500
# 7/7 - 0s - loss: 5.0573 - mean_absolute_error: 1.7003 - 17ms/epoch - 2ms/step
# Epoch 213/500
# 7/7 - 0s - loss: 5.0444 - mean_absolute_error: 1.7006 - 16ms/epoch - 2ms/step
# Epoch 214/500
# 7/7 - 0s - loss: 4.8641 - mean_absolute_error: 1.6530 - 17ms/epoch - 2ms/step
# Epoch 215/500
# 7/7 - 0s - loss: 4.7975 - mean_absolute_error: 1.6467 - 17ms/epoch - 2ms/step
# Epoch 216/500
# 7/7 - 0s - loss: 4.8912 - mean_absolute_error: 1.6678 - 17ms/epoch - 2ms/step
# Epoch 217/500
# 7/7 - 0s - loss: 5.0479 - mean_absolute_error: 1.6721 - 16ms/epoch - 2ms/step
# Epoch 218/500
# 7/7 - 0s - loss: 4.7126 - mean_absolute_error: 1.6387 - 16ms/epoch - 2ms/step
# Epoch 219/500
# 7/7 - 0s - loss: 4.8505 - mean_absolute_error: 1.6571 - 17ms/epoch - 2ms/step
# Epoch 220/500
# 7/7 - 0s - loss: 4.7961 - mean_absolute_error: 1.6498 - 17ms/epoch - 2ms/step
# Epoch 221/500
# 7/7 - 0s - loss: 4.7148 - mean_absolute_error: 1.6307 - 17ms/epoch - 2ms/step
# Epoch 222/500
# 7/7 - 0s - loss: 4.7378 - mean_absolute_error: 1.6352 - 16ms/epoch - 2ms/step
# Epoch 223/500
# 7/7 - 0s - loss: 4.6831 - mean_absolute_error: 1.6243 - 17ms/epoch - 2ms/step
# Epoch 224/500
# 7/7 - 0s - loss: 4.8034 - mean_absolute_error: 1.6604 - 17ms/epoch - 2ms/step
# Epoch 225/500
# 7/7 - 0s - loss: 4.6482 - mean_absolute_error: 1.6284 - 17ms/epoch - 2ms/step
# Epoch 226/500
# 7/7 - 0s - loss: 4.6750 - mean_absolute_error: 1.6289 - 17ms/epoch - 2ms/step
# Epoch 227/500
# 7/7 - 0s - loss: 4.6602 - mean_absolute_error: 1.6291 - 17ms/epoch - 2ms/step
# Epoch 228/500
# 7/7 - 0s - loss: 4.6740 - mean_absolute_error: 1.6291 - 17ms/epoch - 2ms/step
# Epoch 229/500
# 7/7 - 0s - loss: 4.6539 - mean_absolute_error: 1.6263 - 17ms/epoch - 2ms/step
# Epoch 230/500
# 7/7 - 0s - loss: 4.7970 - mean_absolute_error: 1.6544 - 17ms/epoch - 2ms/step
# Epoch 231/500
# 7/7 - 0s - loss: 4.5747 - mean_absolute_error: 1.6132 - 17ms/epoch - 2ms/step
# Epoch 232/500
# 7/7 - 0s - loss: 4.6389 - mean_absolute_error: 1.6190 - 17ms/epoch - 2ms/step
# Epoch 233/500
# 7/7 - 0s - loss: 4.6972 - mean_absolute_error: 1.6502 - 17ms/epoch - 2ms/step
# Epoch 234/500
# 7/7 - 0s - loss: 4.7883 - mean_absolute_error: 1.6533 - 16ms/epoch - 2ms/step
# Epoch 235/500
# 7/7 - 0s - loss: 4.7224 - mean_absolute_error: 1.6347 - 17ms/epoch - 2ms/step
# Epoch 236/500
# 7/7 - 0s - loss: 4.6145 - mean_absolute_error: 1.6494 - 17ms/epoch - 2ms/step
# Epoch 237/500
# 7/7 - 0s - loss: 4.7185 - mean_absolute_error: 1.6364 - 17ms/epoch - 2ms/step
# Epoch 238/500
# 7/7 - 0s - loss: 4.7326 - mean_absolute_error: 1.6508 - 17ms/epoch - 2ms/step
# Epoch 239/500
# 7/7 - 0s - loss: 4.5707 - mean_absolute_error: 1.6310 - 17ms/epoch - 2ms/step
# Epoch 240/500
# 7/7 - 0s - loss: 4.6554 - mean_absolute_error: 1.6214 - 17ms/epoch - 2ms/step
# Epoch 241/500
# 7/7 - 0s - loss: 4.5519 - mean_absolute_error: 1.6091 - 17ms/epoch - 2ms/step
# Epoch 242/500
# 7/7 - 0s - loss: 4.4998 - mean_absolute_error: 1.6014 - 17ms/epoch - 2ms/step
# Epoch 243/500
# 7/7 - 0s - loss: 4.4743 - mean_absolute_error: 1.6010 - 17ms/epoch - 2ms/step
# Epoch 244/500
# 7/7 - 0s - loss: 4.7354 - mean_absolute_error: 1.6354 - 16ms/epoch - 2ms/step
# Epoch 245/500
# 7/7 - 0s - loss: 4.7711 - mean_absolute_error: 1.6417 - 17ms/epoch - 2ms/step
# Epoch 246/500
# 7/7 - 0s - loss: 4.7207 - mean_absolute_error: 1.6529 - 17ms/epoch - 2ms/step
# Epoch 247/500
# 7/7 - 0s - loss: 4.6230 - mean_absolute_error: 1.6399 - 17ms/epoch - 2ms/step
# Epoch 248/500
# 7/7 - 0s - loss: 4.4874 - mean_absolute_error: 1.6008 - 17ms/epoch - 2ms/step
# Epoch 249/500
# 7/7 - 0s - loss: 4.5009 - mean_absolute_error: 1.6076 - 17ms/epoch - 2ms/step
# Epoch 250/500
# 7/7 - 0s - loss: 4.5235 - mean_absolute_error: 1.6180 - 17ms/epoch - 2ms/step
# Epoch 251/500
# 7/7 - 0s - loss: 4.4851 - mean_absolute_error: 1.6041 - 17ms/epoch - 2ms/step
# Epoch 252/500
# 7/7 - 0s - loss: 4.3958 - mean_absolute_error: 1.5804 - 17ms/epoch - 2ms/step
# Epoch 253/500
# 7/7 - 0s - loss: 4.3725 - mean_absolute_error: 1.5845 - 16ms/epoch - 2ms/step
# Epoch 254/500
# 7/7 - 0s - loss: 4.3789 - mean_absolute_error: 1.5846 - 17ms/epoch - 2ms/step
# Epoch 255/500
# 7/7 - 0s - loss: 4.3625 - mean_absolute_error: 1.5893 - 17ms/epoch - 2ms/step
# Epoch 256/500
# 7/7 - 0s - loss: 4.6707 - mean_absolute_error: 1.6424 - 17ms/epoch - 2ms/step
# Epoch 257/500
# 7/7 - 0s - loss: 4.5398 - mean_absolute_error: 1.6110 - 18ms/epoch - 3ms/step
# Epoch 258/500
# 7/7 - 0s - loss: 4.6426 - mean_absolute_error: 1.6451 - 17ms/epoch - 2ms/step
# Epoch 259/500
# 7/7 - 0s - loss: 4.4343 - mean_absolute_error: 1.5922 - 17ms/epoch - 2ms/step
# Epoch 260/500
# 7/7 - 0s - loss: 4.3538 - mean_absolute_error: 1.5793 - 17ms/epoch - 2ms/step
# Epoch 261/500
# 7/7 - 0s - loss: 4.4336 - mean_absolute_error: 1.6058 - 17ms/epoch - 2ms/step
# Epoch 262/500
# 7/7 - 0s - loss: 4.3211 - mean_absolute_error: 1.5847 - 17ms/epoch - 2ms/step
# Epoch 263/500
# 7/7 - 0s - loss: 4.3114 - mean_absolute_error: 1.5766 - 17ms/epoch - 2ms/step
# Epoch 264/500
# 7/7 - 0s - loss: 4.4432 - mean_absolute_error: 1.6055 - 17ms/epoch - 2ms/step
# Epoch 265/500
# 7/7 - 0s - loss: 4.3501 - mean_absolute_error: 1.5907 - 17ms/epoch - 2ms/step
# Epoch 266/500
# 7/7 - 0s - loss: 4.2742 - mean_absolute_error: 1.5682 - 17ms/epoch - 2ms/step
# Epoch 267/500
# 7/7 - 0s - loss: 4.2904 - mean_absolute_error: 1.5697 - 16ms/epoch - 2ms/step
# Epoch 268/500
# 7/7 - 0s - loss: 4.3244 - mean_absolute_error: 1.5742 - 16ms/epoch - 2ms/step
# Epoch 269/500
# 7/7 - 0s - loss: 4.3236 - mean_absolute_error: 1.5918 - 16ms/epoch - 2ms/step
# Epoch 270/500
# 7/7 - 0s - loss: 4.3414 - mean_absolute_error: 1.5783 - 17ms/epoch - 2ms/step
# Epoch 271/500
# 7/7 - 0s - loss: 4.2805 - mean_absolute_error: 1.5716 - 17ms/epoch - 2ms/step
# Epoch 272/500
# 7/7 - 0s - loss: 4.2967 - mean_absolute_error: 1.5707 - 16ms/epoch - 2ms/step
# Epoch 273/500
# 7/7 - 0s - loss: 4.3954 - mean_absolute_error: 1.6010 - 17ms/epoch - 2ms/step
# Epoch 274/500
# 7/7 - 0s - loss: 4.4230 - mean_absolute_error: 1.6030 - 16ms/epoch - 2ms/step
# Epoch 275/500
# 7/7 - 0s - loss: 4.3837 - mean_absolute_error: 1.5780 - 16ms/epoch - 2ms/step
# Epoch 276/500
# 7/7 - 0s - loss: 4.2820 - mean_absolute_error: 1.5729 - 17ms/epoch - 2ms/step
# Epoch 277/500
# 7/7 - 0s - loss: 4.3076 - mean_absolute_error: 1.5927 - 17ms/epoch - 2ms/step
# Epoch 278/500
# 7/7 - 0s - loss: 4.6001 - mean_absolute_error: 1.6386 - 17ms/epoch - 2ms/step
# Epoch 279/500
# 7/7 - 0s - loss: 4.4338 - mean_absolute_error: 1.6281 - 16ms/epoch - 2ms/step
# Epoch 280/500
# 7/7 - 0s - loss: 4.2259 - mean_absolute_error: 1.5673 - 17ms/epoch - 2ms/step
# Epoch 281/500
# 7/7 - 0s - loss: 4.2784 - mean_absolute_error: 1.5767 - 17ms/epoch - 2ms/step
# Epoch 282/500
# 7/7 - 0s - loss: 4.1349 - mean_absolute_error: 1.5480 - 16ms/epoch - 2ms/step
# Epoch 283/500
# 7/7 - 0s - loss: 4.1690 - mean_absolute_error: 1.5608 - 17ms/epoch - 2ms/step
# Epoch 284/500
# 7/7 - 0s - loss: 4.2097 - mean_absolute_error: 1.5383 - 17ms/epoch - 2ms/step
# Epoch 285/500
# 7/7 - 0s - loss: 4.1792 - mean_absolute_error: 1.5581 - 17ms/epoch - 2ms/step
# Epoch 286/500
# 7/7 - 0s - loss: 4.1265 - mean_absolute_error: 1.5476 - 17ms/epoch - 2ms/step
# Epoch 287/500
# 7/7 - 0s - loss: 4.1797 - mean_absolute_error: 1.5538 - 17ms/epoch - 2ms/step
# Epoch 288/500
# 7/7 - 0s - loss: 4.1999 - mean_absolute_error: 1.5562 - 16ms/epoch - 2ms/step
# Epoch 289/500
# 7/7 - 0s - loss: 4.1665 - mean_absolute_error: 1.5579 - 17ms/epoch - 2ms/step
# Epoch 290/500
# 7/7 - 0s - loss: 4.1212 - mean_absolute_error: 1.5458 - 17ms/epoch - 2ms/step
# Epoch 291/500
# 7/7 - 0s - loss: 4.1081 - mean_absolute_error: 1.5413 - 17ms/epoch - 2ms/step
# Epoch 292/500
# 7/7 - 0s - loss: 4.0612 - mean_absolute_error: 1.5374 - 16ms/epoch - 2ms/step
# Epoch 293/500
# 7/7 - 0s - loss: 4.1958 - mean_absolute_error: 1.5504 - 16ms/epoch - 2ms/step
# Epoch 294/500
# 7/7 - 0s - loss: 4.1043 - mean_absolute_error: 1.5395 - 17ms/epoch - 2ms/step
# Epoch 295/500
# 7/7 - 0s - loss: 4.0719 - mean_absolute_error: 1.5352 - 17ms/epoch - 2ms/step
# Epoch 296/500
# 7/7 - 0s - loss: 4.0623 - mean_absolute_error: 1.5352 - 19ms/epoch - 3ms/step
# Epoch 297/500
# 7/7 - 0s - loss: 4.0678 - mean_absolute_error: 1.5382 - 19ms/epoch - 3ms/step
# Epoch 298/500
# 7/7 - 0s - loss: 4.3625 - mean_absolute_error: 1.5883 - 18ms/epoch - 3ms/step
# Epoch 299/500
# 7/7 - 0s - loss: 4.4241 - mean_absolute_error: 1.6321 - 17ms/epoch - 2ms/step
# Epoch 300/500
# 7/7 - 0s - loss: 4.2196 - mean_absolute_error: 1.5754 - 18ms/epoch - 3ms/step
# Epoch 301/500
# 7/7 - 0s - loss: 4.0309 - mean_absolute_error: 1.5298 - 18ms/epoch - 3ms/step
# Epoch 302/500
# 7/7 - 0s - loss: 4.0267 - mean_absolute_error: 1.5241 - 18ms/epoch - 3ms/step
# Epoch 303/500
# 7/7 - 0s - loss: 4.0762 - mean_absolute_error: 1.5419 - 18ms/epoch - 3ms/step
# Epoch 304/500
# 7/7 - 0s - loss: 4.0653 - mean_absolute_error: 1.5337 - 17ms/epoch - 2ms/step
# Epoch 305/500
# 7/7 - 0s - loss: 4.0420 - mean_absolute_error: 1.5269 - 17ms/epoch - 2ms/step
# Epoch 306/500
# 7/7 - 0s - loss: 4.0682 - mean_absolute_error: 1.5483 - 18ms/epoch - 3ms/step
# Epoch 307/500
# 7/7 - 0s - loss: 4.2457 - mean_absolute_error: 1.5814 - 17ms/epoch - 2ms/step
# Epoch 308/500
# 7/7 - 0s - loss: 4.0062 - mean_absolute_error: 1.5274 - 17ms/epoch - 2ms/step
# Epoch 309/500
# 7/7 - 0s - loss: 4.0146 - mean_absolute_error: 1.5320 - 17ms/epoch - 2ms/step
# Epoch 310/500
# 7/7 - 0s - loss: 4.0148 - mean_absolute_error: 1.5253 - 18ms/epoch - 3ms/step
# Epoch 311/500
# 7/7 - 0s - loss: 3.9929 - mean_absolute_error: 1.5256 - 18ms/epoch - 3ms/step
# Epoch 312/500
# 7/7 - 0s - loss: 4.0332 - mean_absolute_error: 1.5311 - 17ms/epoch - 2ms/step
# Epoch 313/500
# 7/7 - 0s - loss: 3.9799 - mean_absolute_error: 1.5262 - 17ms/epoch - 2ms/step
# Epoch 314/500
# 7/7 - 0s - loss: 3.9628 - mean_absolute_error: 1.5144 - 18ms/epoch - 3ms/step
# Epoch 315/500
# 7/7 - 0s - loss: 4.1096 - mean_absolute_error: 1.5595 - 18ms/epoch - 3ms/step
# Epoch 316/500
# 7/7 - 0s - loss: 4.0864 - mean_absolute_error: 1.5529 - 17ms/epoch - 2ms/step
# Epoch 317/500
# 7/7 - 0s - loss: 4.0011 - mean_absolute_error: 1.5274 - 16ms/epoch - 2ms/step
# Epoch 318/500
# 7/7 - 0s - loss: 4.0397 - mean_absolute_error: 1.5362 - 17ms/epoch - 2ms/step
# Epoch 319/500
# 7/7 - 0s - loss: 3.9371 - mean_absolute_error: 1.5134 - 17ms/epoch - 2ms/step
# Epoch 320/500
# 7/7 - 0s - loss: 4.0633 - mean_absolute_error: 1.5406 - 17ms/epoch - 2ms/step
# Epoch 321/500
# 7/7 - 0s - loss: 3.9661 - mean_absolute_error: 1.5265 - 17ms/epoch - 2ms/step
# Epoch 322/500
# 7/7 - 0s - loss: 4.0460 - mean_absolute_error: 1.5399 - 17ms/epoch - 2ms/step
# Epoch 323/500
# 7/7 - 0s - loss: 3.9377 - mean_absolute_error: 1.5137 - 17ms/epoch - 2ms/step
# Epoch 324/500
# 7/7 - 0s - loss: 3.9193 - mean_absolute_error: 1.5110 - 16ms/epoch - 2ms/step
# Epoch 325/500
# 7/7 - 0s - loss: 4.0248 - mean_absolute_error: 1.5425 - 17ms/epoch - 2ms/step
# Epoch 326/500
# 7/7 - 0s - loss: 4.0016 - mean_absolute_error: 1.5212 - 16ms/epoch - 2ms/step
# Epoch 327/500
# 7/7 - 0s - loss: 3.9879 - mean_absolute_error: 1.5251 - 17ms/epoch - 2ms/step
# Epoch 328/500
# 7/7 - 0s - loss: 3.9646 - mean_absolute_error: 1.5205 - 17ms/epoch - 2ms/step
# Epoch 329/500
# 7/7 - 0s - loss: 3.9764 - mean_absolute_error: 1.5355 - 18ms/epoch - 3ms/step
# Epoch 330/500
# 7/7 - 0s - loss: 3.9776 - mean_absolute_error: 1.5260 - 18ms/epoch - 3ms/step
# Epoch 331/500
# 7/7 - 0s - loss: 4.0891 - mean_absolute_error: 1.5466 - 18ms/epoch - 3ms/step
# Epoch 332/500
# 7/7 - 0s - loss: 3.9364 - mean_absolute_error: 1.5170 - 17ms/epoch - 2ms/step
# Epoch 333/500
# 7/7 - 0s - loss: 3.8916 - mean_absolute_error: 1.5047 - 18ms/epoch - 3ms/step
# Epoch 334/500
# 7/7 - 0s - loss: 3.8806 - mean_absolute_error: 1.5021 - 17ms/epoch - 2ms/step
# Epoch 335/500
# 7/7 - 0s - loss: 3.8555 - mean_absolute_error: 1.5011 - 18ms/epoch - 3ms/step
# Epoch 336/500
# 7/7 - 0s - loss: 3.8587 - mean_absolute_error: 1.4992 - 17ms/epoch - 2ms/step
# Epoch 337/500
# 7/7 - 0s - loss: 3.8638 - mean_absolute_error: 1.5025 - 18ms/epoch - 3ms/step
# Epoch 338/500
# 7/7 - 0s - loss: 3.8617 - mean_absolute_error: 1.5056 - 18ms/epoch - 3ms/step
# Epoch 339/500
# 7/7 - 0s - loss: 3.8700 - mean_absolute_error: 1.5041 - 17ms/epoch - 2ms/step
# Epoch 340/500
# 7/7 - 0s - loss: 3.8399 - mean_absolute_error: 1.4957 - 17ms/epoch - 2ms/step
# Epoch 341/500
# 7/7 - 0s - loss: 3.8642 - mean_absolute_error: 1.5057 - 18ms/epoch - 3ms/step
# Epoch 342/500
# 7/7 - 0s - loss: 4.0575 - mean_absolute_error: 1.5476 - 18ms/epoch - 3ms/step
# Epoch 343/500
# 7/7 - 0s - loss: 4.0667 - mean_absolute_error: 1.5412 - 17ms/epoch - 2ms/step
# Epoch 344/500
# 7/7 - 0s - loss: 3.9119 - mean_absolute_error: 1.5041 - 18ms/epoch - 3ms/step
# Epoch 345/500
# 7/7 - 0s - loss: 3.9130 - mean_absolute_error: 1.5167 - 17ms/epoch - 2ms/step
# Epoch 346/500
# 7/7 - 0s - loss: 3.8240 - mean_absolute_error: 1.4943 - 18ms/epoch - 3ms/step
# Epoch 347/500
# 7/7 - 0s - loss: 3.8530 - mean_absolute_error: 1.4980 - 18ms/epoch - 3ms/step
# Epoch 348/500
# 7/7 - 0s - loss: 3.8680 - mean_absolute_error: 1.5009 - 17ms/epoch - 2ms/step
# Epoch 349/500
# 7/7 - 0s - loss: 4.0217 - mean_absolute_error: 1.5599 - 17ms/epoch - 2ms/step
# Epoch 350/500
# 7/7 - 0s - loss: 3.8703 - mean_absolute_error: 1.5072 - 17ms/epoch - 2ms/step
# Epoch 351/500
# 7/7 - 0s - loss: 3.8209 - mean_absolute_error: 1.4888 - 17ms/epoch - 2ms/step
# Epoch 352/500
# 7/7 - 0s - loss: 3.8279 - mean_absolute_error: 1.4951 - 18ms/epoch - 3ms/step
# Epoch 353/500
# 7/7 - 0s - loss: 3.8217 - mean_absolute_error: 1.4910 - 17ms/epoch - 2ms/step
# Epoch 354/500
# 7/7 - 0s - loss: 3.8190 - mean_absolute_error: 1.4954 - 17ms/epoch - 2ms/step
# Epoch 355/500
# 7/7 - 0s - loss: 3.8278 - mean_absolute_error: 1.4902 - 17ms/epoch - 2ms/step
# Epoch 356/500
# 7/7 - 0s - loss: 4.0504 - mean_absolute_error: 1.5552 - 17ms/epoch - 2ms/step
# Epoch 357/500
# 7/7 - 0s - loss: 3.8048 - mean_absolute_error: 1.5035 - 17ms/epoch - 2ms/step
# Epoch 358/500
# 7/7 - 0s - loss: 3.8485 - mean_absolute_error: 1.4935 - 17ms/epoch - 2ms/step
# Epoch 359/500
# 7/7 - 0s - loss: 3.8251 - mean_absolute_error: 1.4962 - 17ms/epoch - 2ms/step
# Epoch 360/500
# 7/7 - 0s - loss: 3.7534 - mean_absolute_error: 1.4821 - 16ms/epoch - 2ms/step
# Epoch 361/500
# 7/7 - 0s - loss: 3.7723 - mean_absolute_error: 1.4878 - 17ms/epoch - 2ms/step
# Epoch 362/500
# 7/7 - 0s - loss: 3.7568 - mean_absolute_error: 1.4838 - 17ms/epoch - 2ms/step
# Epoch 363/500
# 7/7 - 0s - loss: 3.7270 - mean_absolute_error: 1.4760 - 17ms/epoch - 2ms/step
# Epoch 364/500
# 7/7 - 0s - loss: 3.7758 - mean_absolute_error: 1.4875 - 16ms/epoch - 2ms/step
# Epoch 365/500
# 7/7 - 0s - loss: 3.7674 - mean_absolute_error: 1.4864 - 17ms/epoch - 2ms/step
# Epoch 366/500
# 7/7 - 0s - loss: 3.7568 - mean_absolute_error: 1.4758 - 17ms/epoch - 2ms/step
# Epoch 367/500
# 7/7 - 0s - loss: 3.7399 - mean_absolute_error: 1.4831 - 17ms/epoch - 2ms/step
# Epoch 368/500
# 7/7 - 0s - loss: 3.7507 - mean_absolute_error: 1.4782 - 17ms/epoch - 2ms/step
# Epoch 369/500
# 7/7 - 0s - loss: 3.7376 - mean_absolute_error: 1.4814 - 17ms/epoch - 2ms/step
# Epoch 370/500
# 7/7 - 0s - loss: 4.1903 - mean_absolute_error: 1.5799 - 16ms/epoch - 2ms/step
# Epoch 371/500
# 7/7 - 0s - loss: 3.9846 - mean_absolute_error: 1.5196 - 17ms/epoch - 2ms/step
# Epoch 372/500
# 7/7 - 0s - loss: 3.8024 - mean_absolute_error: 1.4951 - 17ms/epoch - 2ms/step
# Epoch 373/500
# 7/7 - 0s - loss: 3.7568 - mean_absolute_error: 1.4850 - 17ms/epoch - 2ms/step
# Epoch 374/500
# 7/7 - 0s - loss: 3.7851 - mean_absolute_error: 1.4771 - 17ms/epoch - 2ms/step
# Epoch 375/500
# 7/7 - 0s - loss: 3.6801 - mean_absolute_error: 1.4732 - 17ms/epoch - 2ms/step
# Epoch 376/500
# 7/7 - 0s - loss: 3.7711 - mean_absolute_error: 1.4797 - 17ms/epoch - 2ms/step
# Epoch 377/500
# 7/7 - 0s - loss: 3.7876 - mean_absolute_error: 1.4878 - 17ms/epoch - 2ms/step
# Epoch 378/500
# 7/7 - 0s - loss: 3.6947 - mean_absolute_error: 1.4674 - 17ms/epoch - 2ms/step
# Epoch 379/500
# 7/7 - 0s - loss: 3.7288 - mean_absolute_error: 1.4829 - 17ms/epoch - 2ms/step
# Epoch 380/500
# 7/7 - 0s - loss: 3.7171 - mean_absolute_error: 1.4727 - 17ms/epoch - 2ms/step
# Epoch 381/500
# 7/7 - 0s - loss: 3.6911 - mean_absolute_error: 1.4702 - 18ms/epoch - 3ms/step
# Epoch 382/500
# 7/7 - 0s - loss: 3.7229 - mean_absolute_error: 1.4696 - 16ms/epoch - 2ms/step
# Epoch 383/500
# 7/7 - 0s - loss: 3.7417 - mean_absolute_error: 1.4809 - 18ms/epoch - 3ms/step
# Epoch 384/500
# 7/7 - 0s - loss: 3.7121 - mean_absolute_error: 1.4803 - 18ms/epoch - 3ms/step
# Epoch 385/500
# 7/7 - 0s - loss: 3.6485 - mean_absolute_error: 1.4606 - 17ms/epoch - 2ms/step
# Epoch 386/500
# 7/7 - 0s - loss: 3.7149 - mean_absolute_error: 1.4740 - 18ms/epoch - 3ms/step
# Epoch 387/500
# 7/7 - 0s - loss: 3.6517 - mean_absolute_error: 1.4600 - 17ms/epoch - 2ms/step
# Epoch 388/500
# 7/7 - 0s - loss: 3.6672 - mean_absolute_error: 1.4606 - 17ms/epoch - 2ms/step
# Epoch 389/500
# 7/7 - 0s - loss: 3.6340 - mean_absolute_error: 1.4586 - 17ms/epoch - 2ms/step
# Epoch 390/500
# 7/7 - 0s - loss: 3.6561 - mean_absolute_error: 1.4655 - 17ms/epoch - 2ms/step
# Epoch 391/500
# 7/7 - 0s - loss: 3.6673 - mean_absolute_error: 1.4630 - 17ms/epoch - 2ms/step
# Epoch 392/500
# 7/7 - 0s - loss: 3.6661 - mean_absolute_error: 1.4763 - 18ms/epoch - 3ms/step
# Epoch 393/500
# 7/7 - 0s - loss: 3.6262 - mean_absolute_error: 1.4632 - 18ms/epoch - 3ms/step
# Epoch 394/500
# 7/7 - 0s - loss: 3.8350 - mean_absolute_error: 1.5033 - 18ms/epoch - 3ms/step
# Epoch 395/500
# 7/7 - 0s - loss: 3.7914 - mean_absolute_error: 1.4983 - 17ms/epoch - 2ms/step
# Epoch 396/500
# 7/7 - 0s - loss: 3.6950 - mean_absolute_error: 1.4751 - 17ms/epoch - 2ms/step
# Epoch 397/500
# 7/7 - 0s - loss: 3.7225 - mean_absolute_error: 1.4846 - 17ms/epoch - 2ms/step
# Epoch 398/500
# 7/7 - 0s - loss: 3.6298 - mean_absolute_error: 1.4502 - 17ms/epoch - 2ms/step
# Epoch 399/500
# 7/7 - 0s - loss: 3.6875 - mean_absolute_error: 1.4853 - 17ms/epoch - 2ms/step
# Epoch 400/500
# 7/7 - 0s - loss: 3.8550 - mean_absolute_error: 1.5379 - 18ms/epoch - 3ms/step
# Epoch 401/500
# 7/7 - 0s - loss: 3.7882 - mean_absolute_error: 1.4873 - 18ms/epoch - 3ms/step
# Epoch 402/500
# 7/7 - 0s - loss: 3.6847 - mean_absolute_error: 1.4819 - 18ms/epoch - 3ms/step
# Epoch 403/500
# 7/7 - 0s - loss: 3.6251 - mean_absolute_error: 1.4629 - 17ms/epoch - 2ms/step
# Epoch 404/500
# 7/7 - 0s - loss: 3.6658 - mean_absolute_error: 1.4641 - 18ms/epoch - 3ms/step
# Epoch 405/500
# 7/7 - 0s - loss: 3.6988 - mean_absolute_error: 1.4732 - 18ms/epoch - 3ms/step
# Epoch 406/500
# 7/7 - 0s - loss: 3.7101 - mean_absolute_error: 1.4905 - 17ms/epoch - 2ms/step
# Epoch 407/500
# 7/7 - 0s - loss: 3.7257 - mean_absolute_error: 1.4746 - 18ms/epoch - 3ms/step
# Epoch 408/500
# 7/7 - 0s - loss: 3.6291 - mean_absolute_error: 1.4694 - 17ms/epoch - 2ms/step
# Epoch 409/500
# 7/7 - 0s - loss: 3.6313 - mean_absolute_error: 1.4609 - 18ms/epoch - 3ms/step
# Epoch 410/500
# 7/7 - 0s - loss: 3.5724 - mean_absolute_error: 1.4420 - 17ms/epoch - 2ms/step
# Epoch 411/500
# 7/7 - 0s - loss: 3.6084 - mean_absolute_error: 1.4634 - 16ms/epoch - 2ms/step
# Epoch 412/500
# 7/7 - 0s - loss: 3.6380 - mean_absolute_error: 1.4620 - 18ms/epoch - 3ms/step
# Epoch 413/500
# 7/7 - 0s - loss: 3.5637 - mean_absolute_error: 1.4456 - 17ms/epoch - 2ms/step
# Epoch 414/500
# 7/7 - 0s - loss: 3.7144 - mean_absolute_error: 1.4877 - 17ms/epoch - 2ms/step
# Epoch 415/500
# 7/7 - 0s - loss: 3.6869 - mean_absolute_error: 1.4835 - 17ms/epoch - 2ms/step
# Epoch 416/500
# 7/7 - 0s - loss: 3.6884 - mean_absolute_error: 1.4830 - 17ms/epoch - 2ms/step
# Epoch 417/500
# 7/7 - 0s - loss: 3.6931 - mean_absolute_error: 1.4804 - 17ms/epoch - 2ms/step
# Epoch 418/500
# 7/7 - 0s - loss: 3.6718 - mean_absolute_error: 1.4891 - 17ms/epoch - 2ms/step
# Epoch 419/500
# 7/7 - 0s - loss: 3.8203 - mean_absolute_error: 1.5171 - 17ms/epoch - 2ms/step
# Epoch 420/500
# 7/7 - 0s - loss: 4.0751 - mean_absolute_error: 1.5691 - 17ms/epoch - 2ms/step
# Epoch 421/500
# 7/7 - 0s - loss: 4.0614 - mean_absolute_error: 1.5431 - 17ms/epoch - 2ms/step
# Epoch 422/500
# 7/7 - 0s - loss: 3.7992 - mean_absolute_error: 1.5071 - 17ms/epoch - 2ms/step
# Epoch 423/500
# 7/7 - 0s - loss: 3.6339 - mean_absolute_error: 1.4826 - 17ms/epoch - 2ms/step
# Epoch 424/500
# 7/7 - 0s - loss: 3.8510 - mean_absolute_error: 1.5085 - 16ms/epoch - 2ms/step
# Epoch 425/500
# 7/7 - 0s - loss: 3.6788 - mean_absolute_error: 1.4788 - 17ms/epoch - 2ms/step
# Epoch 426/500
# 7/7 - 0s - loss: 3.6563 - mean_absolute_error: 1.4685 - 17ms/epoch - 2ms/step
# Epoch 427/500
# 7/7 - 0s - loss: 3.6190 - mean_absolute_error: 1.4685 - 17ms/epoch - 2ms/step
# Epoch 428/500
# 7/7 - 0s - loss: 3.6041 - mean_absolute_error: 1.4560 - 17ms/epoch - 2ms/step
# Epoch 429/500
# 7/7 - 0s - loss: 3.5863 - mean_absolute_error: 1.4586 - 17ms/epoch - 2ms/step
# Epoch 430/500
# 7/7 - 0s - loss: 3.6425 - mean_absolute_error: 1.4572 - 17ms/epoch - 2ms/step
# Epoch 431/500
# 7/7 - 0s - loss: 3.6467 - mean_absolute_error: 1.4800 - 17ms/epoch - 2ms/step
# Epoch 432/500
# 7/7 - 0s - loss: 3.5392 - mean_absolute_error: 1.4479 - 17ms/epoch - 2ms/step
# Epoch 433/500
# 7/7 - 0s - loss: 3.5555 - mean_absolute_error: 1.4431 - 16ms/epoch - 2ms/step
# Epoch 434/500
# 7/7 - 0s - loss: 3.5109 - mean_absolute_error: 1.4361 - 16ms/epoch - 2ms/step
# Epoch 435/500
# 7/7 - 0s - loss: 3.5479 - mean_absolute_error: 1.4518 - 17ms/epoch - 2ms/step
# Epoch 436/500
# 7/7 - 0s - loss: 3.5383 - mean_absolute_error: 1.4513 - 17ms/epoch - 2ms/step
# Epoch 437/500
# 7/7 - 0s - loss: 3.5447 - mean_absolute_error: 1.4500 - 17ms/epoch - 2ms/step
# Epoch 438/500
# 7/7 - 0s - loss: 3.5148 - mean_absolute_error: 1.4389 - 17ms/epoch - 2ms/step
# Epoch 439/500
# 7/7 - 0s - loss: 3.5174 - mean_absolute_error: 1.4334 - 17ms/epoch - 2ms/step
# Epoch 440/500
# 7/7 - 0s - loss: 3.5400 - mean_absolute_error: 1.4488 - 17ms/epoch - 2ms/step
# Epoch 441/500
# 7/7 - 0s - loss: 3.5458 - mean_absolute_error: 1.4590 - 17ms/epoch - 2ms/step
# Epoch 442/500
# 7/7 - 0s - loss: 3.5433 - mean_absolute_error: 1.4561 - 17ms/epoch - 2ms/step
# Epoch 443/500
# 7/7 - 0s - loss: 3.5980 - mean_absolute_error: 1.4486 - 16ms/epoch - 2ms/step
# Epoch 444/500
# 7/7 - 0s - loss: 3.4950 - mean_absolute_error: 1.4278 - 17ms/epoch - 2ms/step
# Epoch 445/500
# 7/7 - 0s - loss: 3.4732 - mean_absolute_error: 1.4280 - 17ms/epoch - 2ms/step
# Epoch 446/500
# 7/7 - 0s - loss: 3.4671 - mean_absolute_error: 1.4287 - 17ms/epoch - 2ms/step
# Epoch 447/500
# 7/7 - 0s - loss: 3.4827 - mean_absolute_error: 1.4230 - 17ms/epoch - 2ms/step
# Epoch 448/500
# 7/7 - 0s - loss: 3.4686 - mean_absolute_error: 1.4273 - 17ms/epoch - 2ms/step
# Epoch 449/500
# 7/7 - 0s - loss: 3.4930 - mean_absolute_error: 1.4324 - 17ms/epoch - 2ms/step
# Epoch 450/500
# 7/7 - 0s - loss: 3.5823 - mean_absolute_error: 1.4724 - 17ms/epoch - 2ms/step
# Epoch 451/500
# 7/7 - 0s - loss: 3.6021 - mean_absolute_error: 1.4697 - 16ms/epoch - 2ms/step
# Epoch 452/500
# 7/7 - 0s - loss: 3.4443 - mean_absolute_error: 1.4243 - 17ms/epoch - 2ms/step
# Epoch 453/500
# 7/7 - 0s - loss: 3.5181 - mean_absolute_error: 1.4413 - 17ms/epoch - 2ms/step
# Epoch 454/500
# 7/7 - 0s - loss: 3.5137 - mean_absolute_error: 1.4437 - 17ms/epoch - 2ms/step
# Epoch 455/500
# 7/7 - 0s - loss: 3.4566 - mean_absolute_error: 1.4308 - 16ms/epoch - 2ms/step
# Epoch 456/500
# 7/7 - 0s - loss: 3.4599 - mean_absolute_error: 1.4321 - 17ms/epoch - 2ms/step
# Epoch 457/500
# 7/7 - 0s - loss: 3.6125 - mean_absolute_error: 1.4595 - 16ms/epoch - 2ms/step
# Epoch 458/500
# 7/7 - 0s - loss: 3.6916 - mean_absolute_error: 1.4842 - 16ms/epoch - 2ms/step
# Epoch 459/500
# 7/7 - 0s - loss: 3.5849 - mean_absolute_error: 1.4574 - 17ms/epoch - 2ms/step
# Epoch 460/500
# 7/7 - 0s - loss: 3.5197 - mean_absolute_error: 1.4394 - 17ms/epoch - 2ms/step
# Epoch 461/500
# 7/7 - 0s - loss: 3.4818 - mean_absolute_error: 1.4278 - 17ms/epoch - 2ms/step
# Epoch 462/500
# 7/7 - 0s - loss: 3.4439 - mean_absolute_error: 1.4247 - 17ms/epoch - 2ms/step
# Epoch 463/500
# 7/7 - 0s - loss: 3.4501 - mean_absolute_error: 1.4292 - 18ms/epoch - 3ms/step
# Epoch 464/500
# 7/7 - 0s - loss: 3.5116 - mean_absolute_error: 1.4398 - 16ms/epoch - 2ms/step
# Epoch 465/500
# 7/7 - 0s - loss: 3.5126 - mean_absolute_error: 1.4534 - 16ms/epoch - 2ms/step
# Epoch 466/500
# 7/7 - 0s - loss: 3.4973 - mean_absolute_error: 1.4386 - 16ms/epoch - 2ms/step
# Epoch 467/500
# 7/7 - 0s - loss: 3.4745 - mean_absolute_error: 1.4362 - 16ms/epoch - 2ms/step
# Epoch 468/500
# 7/7 - 0s - loss: 3.5157 - mean_absolute_error: 1.4532 - 16ms/epoch - 2ms/step
# Epoch 469/500
# 7/7 - 0s - loss: 3.5523 - mean_absolute_error: 1.4454 - 16ms/epoch - 2ms/step
# Epoch 470/500
# 7/7 - 0s - loss: 3.5076 - mean_absolute_error: 1.4365 - 16ms/epoch - 2ms/step
# Epoch 471/500
# 7/7 - 0s - loss: 3.3772 - mean_absolute_error: 1.4189 - 17ms/epoch - 2ms/step
# Epoch 472/500
# 7/7 - 0s - loss: 3.4519 - mean_absolute_error: 1.4346 - 17ms/epoch - 2ms/step
# Epoch 473/500
# 7/7 - 0s - loss: 3.5060 - mean_absolute_error: 1.4502 - 17ms/epoch - 2ms/step
# Epoch 474/500
# 7/7 - 0s - loss: 3.4282 - mean_absolute_error: 1.4212 - 17ms/epoch - 2ms/step
# Epoch 475/500
# 7/7 - 0s - loss: 3.3988 - mean_absolute_error: 1.4151 - 17ms/epoch - 2ms/step
# Epoch 476/500
# 7/7 - 0s - loss: 3.4476 - mean_absolute_error: 1.4186 - 17ms/epoch - 2ms/step
# Epoch 477/500
# 7/7 - 0s - loss: 3.5734 - mean_absolute_error: 1.4517 - 16ms/epoch - 2ms/step
# Epoch 478/500
# 7/7 - 0s - loss: 3.6049 - mean_absolute_error: 1.4684 - 17ms/epoch - 2ms/step
# Epoch 479/500
# 7/7 - 0s - loss: 3.4578 - mean_absolute_error: 1.4419 - 17ms/epoch - 2ms/step
# Epoch 480/500
# 7/7 - 0s - loss: 3.4102 - mean_absolute_error: 1.4226 - 17ms/epoch - 2ms/step
# Epoch 481/500
# 7/7 - 0s - loss: 3.3909 - mean_absolute_error: 1.4116 - 17ms/epoch - 2ms/step
# Epoch 482/500
# 7/7 - 0s - loss: 3.4100 - mean_absolute_error: 1.4188 - 17ms/epoch - 2ms/step
# Epoch 483/500
# 7/7 - 0s - loss: 3.3989 - mean_absolute_error: 1.4136 - 18ms/epoch - 3ms/step
# Epoch 484/500
# 7/7 - 0s - loss: 3.3776 - mean_absolute_error: 1.4097 - 18ms/epoch - 3ms/step
# Epoch 485/500
# 7/7 - 0s - loss: 3.4056 - mean_absolute_error: 1.4173 - 17ms/epoch - 2ms/step
# Epoch 486/500
# 7/7 - 0s - loss: 3.4562 - mean_absolute_error: 1.4311 - 18ms/epoch - 3ms/step
# Epoch 487/500
# 7/7 - 0s - loss: 3.4905 - mean_absolute_error: 1.4454 - 16ms/epoch - 2ms/step
# Epoch 488/500
# 7/7 - 0s - loss: 3.5009 - mean_absolute_error: 1.4384 - 17ms/epoch - 2ms/step
# Epoch 489/500
# 7/7 - 0s - loss: 3.5533 - mean_absolute_error: 1.4557 - 16ms/epoch - 2ms/step
# Epoch 490/500
# 7/7 - 0s - loss: 3.3871 - mean_absolute_error: 1.4133 - 17ms/epoch - 2ms/step
# Epoch 491/500
# 7/7 - 0s - loss: 3.4014 - mean_absolute_error: 1.4224 - 17ms/epoch - 2ms/step
# Epoch 492/500
# 7/7 - 0s - loss: 3.4778 - mean_absolute_error: 1.4502 - 16ms/epoch - 2ms/step
# Epoch 493/500
# 7/7 - 0s - loss: 3.4328 - mean_absolute_error: 1.4247 - 17ms/epoch - 2ms/step
# Epoch 494/500
# 7/7 - 0s - loss: 3.4274 - mean_absolute_error: 1.4208 - 18ms/epoch - 3ms/step
# Epoch 495/500
# 7/7 - 0s - loss: 3.4724 - mean_absolute_error: 1.4413 - 17ms/epoch - 2ms/step
# Epoch 496/500
# 7/7 - 0s - loss: 3.3405 - mean_absolute_error: 1.4084 - 17ms/epoch - 2ms/step
# Epoch 497/500
# 7/7 - 0s - loss: 3.4812 - mean_absolute_error: 1.4329 - 17ms/epoch - 2ms/step
# Epoch 498/500
# 7/7 - 0s - loss: 3.4040 - mean_absolute_error: 1.4193 - 17ms/epoch - 2ms/step
# Epoch 499/500
# 7/7 - 0s - loss: 3.5086 - mean_absolute_error: 1.4449 - 17ms/epoch - 2ms/step
# Epoch 500/500
# 7/7 - 0s - loss: 3.3593 - mean_absolute_error: 1.4121 - 17ms/epoch - 2ms/step

# %% [markdown]
# #plot training history
# plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
#make predictions and evaluate model
y_pred = model.predict(X_test_reshaped)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
y_test.shape
# Out:
# (60,)

# %%
y_pred_flat = y_pred.flatten()

# %%
#evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 #evaluate the model
# ----> 2 mse = mean_squared_error(y_test, y_pred)
#       3 rmse = np.sqrt(mse)
#       4 print("Mean Squared Error:", mse)
#
# File ~/opt/anaconda3/envs/UdacityProject/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/opt/anaconda3/envs/UdacityProject/lib/python3.9/site-packages/sklearn/metrics/_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/opt/anaconda3/envs/UdacityProject/lib/python3.9/site-packages/sklearn/metrics/_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99 check_consistent_length(y_true, y_pred)
#     100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#     104     y_true = y_true.reshape((-1, 1))
#
# File ~/opt/anaconda3/envs/UdacityProject/lib/python3.9/site-packages/sklearn/utils/validation.py:953, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#     952 if not allow_nd and array.ndim >= 3:
# --> 953     raise ValueError(
#     954         "Found array with dim %d. %s expected <= 2."
#     955         % (array.ndim, estimator_name)
#     956     )
#     958 if force_all_finite:
#     959     _assert_all_finite(
#     960         array,
#     961         input_name=input_name,
#     962         estimator_name=estimator_name,
#     963         allow_nan=force_all_finite == "allow-nan",
#     964     )
#
# ValueError: Found array with dim 3. None expected <= 2.

# %%
#define a function to calculate MAPE, my objective is to achieve +/- 5% accuracy
def mean_absolute_percentage_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# 4.55570928383129

# %%
y_test, y_pred
# Out:
# (Date
#  2023-06-15    92.940002
#  2023-06-16    91.320000
#  2023-06-20    89.750000
#  2023-06-21    88.639999
#  2023-06-22    88.489998
#  2023-06-23    88.099998
#  2023-06-26    88.699997
#  2023-06-27    89.059998
#  2023-06-28    88.830002
#  2023-06-29    88.949997
#  2023-06-30    89.279999
#  2023-07-03    90.500000
#  2023-07-05    89.790001
#  2023-07-06    88.739998
#  2023-07-07    88.639999
#  2023-07-10    88.099998
#  2023-07-11    89.489998
#  2023-07-12    90.150002
#  2023-07-13    90.470001
#  2023-07-14    88.620003
#  2023-07-17    85.559998
#  2023-07-18    85.949997
#  2023-07-19    87.040001
#  2023-07-20    86.209999
#  2023-07-21    87.180000
#  2023-07-24    86.599998
#  2023-07-25    85.629997
#  2023-07-26    85.860001
#  2023-07-27    85.360001
#  2023-07-28    86.129997
#  Name: Adj Close, dtype: float64,
#  array([[92.645164],
#         [93.11324 ],
#         [90.739044],
#         [89.72122 ],
#         [88.35033 ],
#         [87.50226 ],
#         [88.055435],
#         [89.01842 ],
#         [89.41308 ],
#         [87.54196 ],
#         [89.32858 ],
#         [89.67361 ],
#         [90.35808 ],
#         [88.412445],
#         [88.40946 ],
#         [87.946724],
#         [88.345055],
#         [90.57559 ],
#         [90.85968 ],
#         [90.65838 ],
#         [88.14971 ],
#         [81.502144],
#         [84.06281 ],
#         [84.648926],
#         [84.28091 ],
#         [86.36911 ],
#         [80.341   ],
#         [80.196815],
#         [83.6629  ],
#         [81.23731 ]], dtype=float32))
